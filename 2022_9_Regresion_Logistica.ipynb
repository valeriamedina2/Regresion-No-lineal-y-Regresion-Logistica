# %% [markdown]
# <a href="https://colab.research.google.com/github/valeriamedina2/Regresion-No-lineal-y-Regresion-Logistica/blob/main/2022_9_Regresion_Logistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Cargamos librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special
from scipy.optimize import curve_fit
import seaborn as sns
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#Cargar archivo csv desde seaborn
df= pd.read_csv('22_gastos.csv')
df
# Out:
#       Unnamed: 0       Fecha         Folio  \
# 0              0  2022-01-01        280108
# 1              1  2022-01-01        280109
# 2              2  2022-01-01  007817297284
# 3              3  2022-01-01          5595
# 4              4  2022-01-01          5614
# ...          ...         ...           ...
# 2572        2572  2022-12-01        863376
# 2573        2573  2022-12-01    1092957089
# 2574        2574  2022-12-01             4
# 2575        2575  2022-12-01            16
# 2576        2576  2022-12-01            17
#
#                                       UUID            RFC  \
# 0     9DA0E63F-1D47-441F-93D7-C2E05AE4D35E   BLE1512082R9
# 1     7E00E776-A839-4D57-B291-411109164B2F   BLE1512082R9
# 2     BB6585C1-3B54-4130-AFD0-1867C3764821   BNM840515VB1
# 3     B5E4B4EB-6C2F-11EC-BB9D-00155D014009  ZEGC530520V4A
# 4     BB6756D1-6CCD-11EC-947D-00155D014407  ZEGC530520V4A
# ...                                    ...            ...
# 2572  E90DA089-3C3B-45C8-A19C-B8810D222F60   BIN940223KE0
# 2573  D720ED7C-F370-4236-B269-8873ABB78745   BMN930209927
# 2574  0AFD3EB5-F3DD-43EB-B9FA-79D793CFF417   AAE6411055P8
# 2575  E3CA1DA8-581A-5844-80D2-CF0317B3BBEA   AAE6411055P8
# 2576  17178BA2-9CCE-54F8-A4B8-3E5F98D4DB8E   AAE6411055P8
#
#                                               Proveedor  \
# 0                          BEPENSA LEASING S.A. DE C.V.
# 1                          BEPENSA LEASING S.A. DE C.V.
# 2                        BANCO NACIONAL DE MEXICO, S.A.
# 3                      CARLOS ENRIQUE ZERMEÑO GUTIERREZ
# 4                      CARLOS ENRIQUE ZERMEÑO GUTIERREZ
# ...                                                 ...
# 2572  BANCO INVEX, S.A., INSTITUCION DE BANCA MULTIP...
# 2573  BANCO MERCANTIL DEL NORTE SA INSTITUCION DE BA...
# 2574               Aesa Articulos Electricos S.A de C.V
# 2575                          AESA ARTICULOS ELECTRICOS
# 2576                          AESA ARTICULOS ELECTRICOS
#
#                     TIPO GASTO  \
# 0     ARRENDAMIENTO FINANCIERO
# 1     ARRENDAMIENTO FINANCIERO
# 2            COMISION BANCARIA
# 3                      COMPRAS
# 4                      COMPRAS
# ...                        ...
# 2572         COMISION BANCARIA
# 2573         COMISION BANCARIA
# 2574                   COMPRAS
# 2575                   COMPRAS
# 2576                   COMPRAS
#
#                                             Descripción   MP   TC   Importe  \
# 0     AA RENTA EXIGIBLE CL0000006876 18/36 de 03/12/...  PPD  1.0   5551.38
# 1     AA RENTA EXIGIBLE CL0000006877 18/36 de 03/12/...  PPD  1.0   5551.98
# 2                              Servicios de Facturación  PUE  1.0      0.00
# 3                                                  Pago   --  1.0      0.00
# 4                                                  Pago   --  1.0      0.00
# ...                                                 ...  ...  ...       ...
# 2572                             COMISIONES E INTERESES  PUE  1.0      0.00
# 2573                                SERVICIOS BANCARIOS  PUE  1.0  17310.30
# 2574                                               Pago   --   --      0.00
# 2575                                               Pago   --   --      0.00
# 2576                                               Pago   --   --      0.00
#
#          IVA  RET ISR  RET IVA  Otros  TOTAL MX  TOTAL SAT Tipo   Status  \
# 0     888.22      0.0      0.0    0.0   6439.60    6439.60    I  Vigente
# 1     888.32      0.0      0.0    0.0   6440.30    6440.30    I  Vigente
# 2       0.00      0.0      0.0    0.0      0.00       0.00    I  Vigente
# 3       0.00      0.0      0.0    0.0      0.00       0.00    P  Vigente
# 4       0.00      0.0      0.0    0.0      0.00       0.00    P  Vigente
# ...      ...      ...      ...    ...       ...        ...  ...      ...
# 2572    0.00      0.0      0.0    0.0      0.00       0.00    I  Vigente
# 2573  516.32      0.0      0.0    0.0  17826.62   17826.62    I  Vigente
# 2574    0.00      0.0      0.0    0.0      0.00       0.00    P  Vigente
# 2575    0.00      0.0      0.0    0.0      0.00       0.00    P  Vigente
# 2576    0.00      0.0      0.0    0.0      0.00       0.00    P  Vigente
#
#           Poliza
# 0     PE02-ENE22
# 1     PE03-ENE22
# 2             --
# 3             --
# 4             --
# ...          ...
# 2572          --
# 2573          --
# 2574          --
# 2575          --
# 2576          --
#
# [2577 rows x 20 columns]

# %%
#Verificar los valores sin repetirse de una columna
unico = np.unique(df['TIPO GASTO'])
unico
# Out:
# array(['ALIMENTOS', 'ANTICIPO ', 'ANTICIPO COMPRA AUTO',
#        'ARRENDAMIENTO FINANCIERO', 'ARRENDAMIENTO LOCAL', 'CALIBRACIONES',
#        'CAPACITACION', 'CASETAS', 'COMISION BANCARIA', 'COMISION MIXTA',
#        'COMPRA AUTO ', 'COMPRAS', 'COMPRAS ', 'CREDITO ', 'DERECHOS',
#        'ENERGIA ELECTRICA', 'FLETE', 'GASOLINA', 'GASTOS IMPORTACION ',
#        'GERENCIA ADMON', 'HONORARIOS CONTABLES', 'HONORARIOS JURIDICOS',
#        'HONORARIOS PM', 'HOSPEDAJE', 'IMSS/INFONAVIT',
#        'INSTALACION ELECTRICA', 'MAQUILAS', 'MAQUINARIA', 'MEDICOS',
#        'MENSAJERIA', 'MONITOREO CAMARAS ADT', 'MTTO COMPUTO',
#        'MTTO EQUIPO COMPUTO', 'MTTO LOCAL', 'MTTO MAQUINARIA',
#        'MTTO OFICINA ', 'MTTO TRANSPORTE', 'NO DEDUCIBLE', 'PAPELERIA',
#        'PAQUETERIA', 'PEAJES', 'PUBLICIDAD', 'RENTA AUTO',
#        'RENTA COPIADORA', 'SANITIZACION', 'SEGUROS', 'SUBCONTRATOS',
#        'SUELDOS DIRECCION', 'SUSCRIPCIONES', 'TELEFONO', 'TRANSPORTE',
#        'UNIFORMES', 'VALES DESPENSA', 'VARIOS'], dtype=object)

# %%
#Convierto una variable a dicotómica 
df['TIPO GASTO']= df['TIPO GASTO'].replace(['COMPRAS '], "COMPRAS")

# %%
#Convierto una variable a dicotómica 
df['TIPO GASTO']= df['TIPO GASTO'].replace(['ALIMENTOS', 'ARRENDAMIENTO FINANCIERO', 'ARRENDAMIENTO LOCAL',
       'BOTIQUIN', 'CALIBRACIONES', 'CAPACITACION', 'COMBUSTIBLE ',
       'COMISION BANCARIA', 'COMISION MIXTA', 'COMPRA COMPUTADORA ',
       'COMPRA TABLET', 'DERECHOS',
       'ENERGIA ELECTRICA', 'FLETE', 'FLETES', 'GASOLINA',
       'GASTOS IMPORTACION ', 'GERENCIA ADMON', 'GERENCIA VTAS',
       'HONORARIOS CONTABLES', 'HONORARIOS JURIDICOS', 'HONORARIOS PF',
       'HONORARIOS PM', 'HOSPEDAJE', 'HOSPEDAJE ', 'IMSS/INFONAVIT',
       'MAQUILAS', 'MAQUILAS GIC', 'MAQUINARIA', 'MEDICOS', 'MENSAJERIA',
       'MONITOREO CAMARAS ADT', 'MTTO COMPUTO', 'MTTO LOCAL',
       'MTTO MAQUINARIA', 'MTTO OFICINA ', 'MTTO TRANSPORTE',
       'NO DEDUCIBLE', 'PAPELERIA', 'PAQUETERIA', 'PEAJES', 'PUBLICIDAD',
       'RENTA COPIADORA', 'RENTA OFICINA ', 'SANITIZACION', 'SEGUROS',
       'SUELDOS DIRECCION', 'SUELDOS PRODUCCION', 'SUELDOS VENTAS',
       'SUSCRIPCIONES', 'TELEFONO', 'TRANSPORTE', 'UNIFORME',
       'VALES DESPENSA', 'COMPRA TABLET ', 'ENERGIA ELECTRICA','ANTICIPO ', 'ANTICIPO COMPRA AUTO', 'CASETAS', 'COMPRA AUTO ', 'CREDITO ', 'INSTALACION ELECTRICA',
       'MTTO EQUIPO COMPUTO', 'OTROS GASTOS', 'RENTA AUTO',
       'SUBCONTRATOS', 'UNIFORMES', 'VARIOS'], "OTROS GASTOS")

df
# Out:
#       Unnamed: 0       Fecha         Folio  \
# 0              0  2022-01-01        280108
# 1              1  2022-01-01        280109
# 2              2  2022-01-01  007817297284
# 3              3  2022-01-01          5595
# 4              4  2022-01-01          5614
# ...          ...         ...           ...
# 2572        2572  2022-12-01        863376
# 2573        2573  2022-12-01    1092957089
# 2574        2574  2022-12-01             4
# 2575        2575  2022-12-01            16
# 2576        2576  2022-12-01            17
#
#                                       UUID            RFC  \
# 0     9DA0E63F-1D47-441F-93D7-C2E05AE4D35E   BLE1512082R9
# 1     7E00E776-A839-4D57-B291-411109164B2F   BLE1512082R9
# 2     BB6585C1-3B54-4130-AFD0-1867C3764821   BNM840515VB1
# 3     B5E4B4EB-6C2F-11EC-BB9D-00155D014009  ZEGC530520V4A
# 4     BB6756D1-6CCD-11EC-947D-00155D014407  ZEGC530520V4A
# ...                                    ...            ...
# 2572  E90DA089-3C3B-45C8-A19C-B8810D222F60   BIN940223KE0
# 2573  D720ED7C-F370-4236-B269-8873ABB78745   BMN930209927
# 2574  0AFD3EB5-F3DD-43EB-B9FA-79D793CFF417   AAE6411055P8
# 2575  E3CA1DA8-581A-5844-80D2-CF0317B3BBEA   AAE6411055P8
# 2576  17178BA2-9CCE-54F8-A4B8-3E5F98D4DB8E   AAE6411055P8
#
#                                               Proveedor    TIPO GASTO  \
# 0                          BEPENSA LEASING S.A. DE C.V.  OTROS GASTOS
# 1                          BEPENSA LEASING S.A. DE C.V.  OTROS GASTOS
# 2                        BANCO NACIONAL DE MEXICO, S.A.  OTROS GASTOS
# 3                      CARLOS ENRIQUE ZERMEÑO GUTIERREZ       COMPRAS
# 4                      CARLOS ENRIQUE ZERMEÑO GUTIERREZ       COMPRAS
# ...                                                 ...           ...
# 2572  BANCO INVEX, S.A., INSTITUCION DE BANCA MULTIP...  OTROS GASTOS
# 2573  BANCO MERCANTIL DEL NORTE SA INSTITUCION DE BA...  OTROS GASTOS
# 2574               Aesa Articulos Electricos S.A de C.V       COMPRAS
# 2575                          AESA ARTICULOS ELECTRICOS       COMPRAS
# 2576                          AESA ARTICULOS ELECTRICOS       COMPRAS
#
#                                             Descripción   MP   TC   Importe  \
# 0     AA RENTA EXIGIBLE CL0000006876 18/36 de 03/12/...  PPD  1.0   5551.38
# 1     AA RENTA EXIGIBLE CL0000006877 18/36 de 03/12/...  PPD  1.0   5551.98
# 2                              Servicios de Facturación  PUE  1.0      0.00
# 3                                                  Pago   --  1.0      0.00
# 4                                                  Pago   --  1.0      0.00
# ...                                                 ...  ...  ...       ...
# 2572                             COMISIONES E INTERESES  PUE  1.0      0.00
# 2573                                SERVICIOS BANCARIOS  PUE  1.0  17310.30
# 2574                                               Pago   --   --      0.00
# 2575                                               Pago   --   --      0.00
# 2576                                               Pago   --   --      0.00
#
#          IVA  RET ISR  RET IVA  Otros  TOTAL MX  TOTAL SAT Tipo   Status  \
# 0     888.22      0.0      0.0    0.0   6439.60    6439.60    I  Vigente
# 1     888.32      0.0      0.0    0.0   6440.30    6440.30    I  Vigente
# 2       0.00      0.0      0.0    0.0      0.00       0.00    I  Vigente
# 3       0.00      0.0      0.0    0.0      0.00       0.00    P  Vigente
# 4       0.00      0.0      0.0    0.0      0.00       0.00    P  Vigente
# ...      ...      ...      ...    ...       ...        ...  ...      ...
# 2572    0.00      0.0      0.0    0.0      0.00       0.00    I  Vigente
# 2573  516.32      0.0      0.0    0.0  17826.62   17826.62    I  Vigente
# 2574    0.00      0.0      0.0    0.0      0.00       0.00    P  Vigente
# 2575    0.00      0.0      0.0    0.0      0.00       0.00    P  Vigente
# 2576    0.00      0.0      0.0    0.0      0.00       0.00    P  Vigente
#
#           Poliza
# 0     PE02-ENE22
# 1     PE03-ENE22
# 2             --
# 3             --
# 4             --
# ...          ...
# 2572          --
# 2573          --
# 2574          --
# 2575          --
# 2576          --
#
# [2577 rows x 20 columns]

# %%
unico = np.unique(df['TIPO GASTO'])
unico
# Out:
# array(['COMPRAS', 'OTROS GASTOS'], dtype=object)

# %%
#Declaramos las variables dependientes e independientes para la regresión Logística
Vars_Indep= df[['TOTAL MX']]
Var_Dep= df['TIPO GASTO']

# %%
#Redefinimos las variables 
X= Vars_Indep
y= Var_Dep

# %%
#Dividimos el conjunto de datos en la parte de entrenamiento y prueba:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state =None)

# %%
#Se escalan todos los datos
escalar = StandardScaler()

# %%
#Para realizar el escalamiento de las variables “X” tanto de entrenamiento como de prueba, utilizaremos fit_transform
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)

# %%
#Definimos el algoritmo a utilizar
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression()

# %%
#Entrenamos el modelo
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Realizamos una predicción
y_pred = algoritmo.predict(X_test) 
y_pred
# Out:
# array(['OTROS GASTOS', 'OTROS GASTOS', 'OTROS GASTOS', ...,
#        'OTROS GASTOS', 'OTROS GASTOS', 'OTROS GASTOS'], dtype=object)

# %%
#Verifico la matriz de Confusión
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print('Matriz de Confusión:')
print(matriz)
# Out:
# Matriz de Confusión:
# [[  1 498]
#  [  1 531]]

# %%
#Calculo la precisión del modelo
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred, average="weighted", pos_label="COMPRAS")
print('Precisión del modelo:')
print(precision)
# Out:
# Precisión del modelo:
# 0.5082741146895228
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1396: UserWarning: Note that pos_label (set to 'COMPRAS') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(

# %%
#Calculo la exactitud del modelo
from sklearn.metrics import accuracy_score

exactitud = accuracy_score(y_test, y_pred)
print('Exactitud del modelo:')
print(exactitud)
# Out:
# Exactitud del modelo:
# 0.516003879728419

# %%
#Calculo la sensibilidad del modelo
from sklearn.metrics import recall_score

sensibilidad = recall_score(y_test, y_pred, average="weighted", pos_label="COMPRAS")
print('Sensibilidad del modelo:')
print(sensibilidad)
# Out:
# Sensibilidad del modelo:
# 0.516003879728419
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1396: UserWarning: Note that pos_label (set to 'COMPRAS') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(

# %%
# el puntaje F1 que es una combinación entre la precisión y la sensibilidad, para esto importamos f1_score.
#Calculo el Puntaje F1 del modelo
from sklearn.metrics import f1_score

puntajef1 = f1_score(y_test, y_pred, average="weighted", pos_label="COMPRAS")
print('Puntaje F1 del modelo:')
print(puntajef1)
# Out:
# Puntaje F1 del modelo:
# 0.3529866495625661
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1396: UserWarning: Note that pos_label (set to 'COMPRAS') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
