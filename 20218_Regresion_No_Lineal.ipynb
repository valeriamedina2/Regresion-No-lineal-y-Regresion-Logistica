# %% [markdown]
# <a href="https://colab.research.google.com/github/valeriamedina2/Regresion-No-lineal-y-Regresion-Logistica/blob/main/20218_Regresion_No_Lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regresión no lineal y lineal
# ## Equipo 8

# %% [markdown]
# # GASTOS **2021**

# %%
#Cargamos librerias
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special
from scipy.optimize import curve_fit
import seaborn as sns
from sklearn.metrics import r2_score
import pandas as pd

# %%
#Cargar archivo csv desde seaborn
df= pd.read_csv('21_gastos.csv')
df
# Out:
#       Unnamed: 0       FECHA                   FOLIO  \
# 0              0  2021-01-01  0001010100750847116902
# 1              1  2021-01-01  0001010100752163714102
# 2              2  2021-01-01                   19788
# 3              3  2021-01-01                  211781
# 4              4  2021-01-01                  211782
# ...          ...         ...                     ...
# 3030        3030  2021-12-01                  127043
# 3031        3031  2021-12-01                   11740
# 3032        3032  2021-12-01              1092957089
# 3033        3033  2021-12-01                  747826
# 3034        3034  2021-12-01                 1227374
#
#                                       UUID           RFC  \
# 0     71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B  BNM840515VB1
# 1     B8AEDE83-CC76-404C-A611-6B5A87BA561F  BNM840515VB1
# 2     19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7  ESI9612311E7
# 3     EAB26414-DD9A-4E8F-9F5C-05FE24D98E48  BLE1512082R9
# 4     C16F79B5-FB35-4BFC-AF84-708B24F500BB  BLE1512082R9
# ...                                    ...           ...
# 3030  83F82167-0D14-144E-9D76-045C95F25DDD  PGM881128QIA
# 3031  B1C60AE0-02BC-4A33-9513-A280F72B5D06  SME0510105C7
# 3032  255F4A25-5753-4208-8F6B-0B59E5AE4741  BMN930209927
# 3033  D8226E4F-9241-44C3-86A4-CDE9BC932528  BIN940223KE0
# 3034  41770F35-39EF-41A4-8DF4-EE9586CF4549  EFE8908015L3
#
#                                               PROVEEDOR  \
# 0                        BANCO NACIONAL DE MEXICO, S.A.
# 1                        BANCO NACIONAL DE MEXICO, S.A.
# 2                ELECTRONICOS Y SIMILARES, S.A. DE C.V.
# 3                          BEPENSA LEASING S.A. DE C.V.
# 4                          BEPENSA LEASING S.A. DE C.V.
# ...                                                 ...
# 3030       PROMOCIONES GRAFICAS MEXICANAS, S.A. DE C.V.
# 3031                      SPECTRIS MEXICO S DE RL DE CV
# 3032  BANCO MERCANTIL DEL NORTE SA INSTITUCION DE BA...
# 3033  BANCO INVEX, S.A., INSTITUCION DE BANCA MULTIP...
# 3034                      EFECTIVALE S. de R.L. de C.V.
#
#                     TIPO GASTO  \
# 0            COMISION BANCARIA
# 1            COMISION BANCARIA
# 2                      COMPRAS
# 3     ARRENDAMIENTO FINANCIERO
# 4     ARRENDAMIENTO FINANCIERO
# ...                        ...
# 3030                PUBLICIDAD
# 3031                  COMPRAS
# 3032         COMISION BANCARIA
# 3033         COMISION BANCARIA
# 3034                  GASOLINA
#
#                                             DESCRIPCION   MP   TC   IMPORTE  \
# 0                                      COMISION COBRADA  PUE  1.0    490.00
# 1                                      COMISION COBRADA  PUE  1.0    345.00
# 2                           MOTO E7 PLUS AZUL 64GB 4RAM  PUE  1.0   3447.41
# 3     AA RENTA EXIGIBLE CL0000006876 6/36 de 03/12/2...  PPD  1.0   5551.38
# 4     AA RENTA EXIGIBLE CL0000006877 6/36 de 03/12/2...  PPD  1.0   5551.98
# ...                                                 ...  ...  ...       ...
# 3030                                               Pago   --  1.0      0.00
# 3031                                 INSULATED T/C WIRE  PUE  1.0      0.00
# 3032                                SERVICIOS BANCARIOS  PUE  1.0  22826.46
# 3033                             COMISIONES E INTERESES  PUE  1.0      0.00
# 3034  CONSUMOS DE COMBUSTIBLE DE MONEDEROS ELECTRONICOS  PUE  1.0  15656.15
#
#          IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT TIPO   STATUS POLIZA
# 0      78.40      0.0      0.0    568.40     568.40    I  Vigente      0
# 1      55.20      0.0      0.0    400.20     400.20    I  Vigente      0
# 2     551.59      0.0      0.0   3999.00    3999.00    I  Vigente      0
# 3     888.22      0.0      0.0   6439.60    6439.60    I  Vigente      0
# 4     888.32      0.0      0.0   6440.30    6440.30    I  Vigente      0
# ...      ...      ...      ...       ...        ...  ...      ...    ...
# 3030    0.00      0.0      0.0      0.00       0.00    P  Vigente     --
# 3031    0.00      0.0      0.0      0.00       0.00    I  Vigente     --
# 3032  705.58      0.0      0.0  23532.04   23532.04    I  Vigente     --
# 3033    0.00      0.0      0.0      0.00       0.00    I  Vigente     --
# 3034    0.00      0.0      0.0  15656.15   15656.15    I  Vigente     --
#
# [3035 rows x 19 columns]

# %%
#Graficamos todas las dispersiones entre todas las variables
sns.pairplot(df)

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
Vars_Indep= df[['IVA']]
Var_Dep= df['TOTAL MX']

# %%
#Redefinimos las variables 
x= Vars_Indep
y= Var_Dep

# %% [markdown]
#    ** Usamos las siguientes ecuaciones como funciones de ajuste.**
#
#             y = ax^2 + bx + c
#
#             y = ax^3 + bx + c
#
#             y = ax^3 + bx^2 + c
#
#             y = a*exp(bx) + c

# %% [markdown]
# **MODELO 1**

# %%
def  func1 (x, a, b, c):
     return a*x**2 + b*x + c

# %%
#Ajustamos los parámetros de la función curve_fit
parametros, covs= curve_fit(func1, df['IVA'], df['TOTAL MX'])

# %%
#Obtenemos los coeficientes del modelo de regresión no lineal
parametros
# Out:
# array([1.17615811e-05, 6.74758108e+00, 7.08455073e+02])

# %%
#Creamos el modelo de predicción con los parámetros obtenidos 
parametros, _ = curve_fit(func1, df['IVA'], df['TOTAL MX'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfit1 = a * x ** 2 + b * x + c

# %%
#Calculamos las predicciones y reestructuramos el vector de predicciones
#x= x.reshape(51, 1)
#y = y.reshape(51, 1)
#yfit1 = yfit1.reshape(51, 1)
yfit1
# Out:
#               IVA
# 0     1237.537723
# 1     1080.957387
# 2     4433.931800
# 3     6711.070660
# 4     6711.747508
# ...           ...
# 3030   708.455073
# 3031   708.455073
# 3032  5475.268754
# 3033   708.455073
# 3034   708.455073
#
# [3035 rows x 1 columns]

# %%
#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, yfit1, label="y=a*x^2+b*x+c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
#Calculamos el coeficiente de determinación del modelo

R2 = r2_score(y, yfit1) 
R2
# Out:
# 0.9028388872975792

# %% [markdown]
# **MODELO 2**

# %% [markdown]
# Regresion lineal

# %%
#Imprimimos el scatter plot entre la variable dependiente (total) e independiente (alchool) 
#para observar el comportamiento en su dispersión 
from turtle import color


sns.scatterplot(x='IVA', y='TOTAL MX', color="blue", data=df)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='IVA', ylabel='TOTAL MX'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= df[['IVA']]
Var_Dep= df['TOTAL MX']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Verificamos la función relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['IVA'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([7.00525121]),
#  'rank_': 1,
#  'singular_': array([89431.55074884]),
#  'intercept_': 590.5357246619342}

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.9019362036138808

# %%
#Predecimos los valores de total de accidentes a partir de la variable "alcohol"
#y_pred= model.predict(X=df[['alcohol', 'speeding']])
y_pred= model.predict(X=df[['IVA']])
y_pred
# Out:
# array([1139.74741973,  977.2255916 , 4454.56224104, ..., 5533.30087527,
#         590.53572466,  590.53572466])

# %%
#Insertamos la columna de predicciones en el DataFrame
df.insert(0, 'Predicciones', y_pred)
df
# Out:
#       Predicciones  Unnamed: 0       FECHA                   FOLIO  \
# 0      1139.747420           0  2021-01-01  0001010100750847116902
# 1       977.225592           1  2021-01-01  0001010100752163714102
# 2      4454.562241           2  2021-01-01                   19788
# 3      6812.739957           3  2021-01-01                  211781
# 4      6813.440482           4  2021-01-01                  211782
# ...            ...         ...         ...                     ...
# 3030    590.535725        3030  2021-12-01                  127043
# 3031    590.535725        3031  2021-12-01                   11740
# 3032   5533.300875        3032  2021-12-01              1092957089
# 3033    590.535725        3033  2021-12-01                  747826
# 3034    590.535725        3034  2021-12-01                 1227374
#
#                                       UUID           RFC  \
# 0     71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B  BNM840515VB1
# 1     B8AEDE83-CC76-404C-A611-6B5A87BA561F  BNM840515VB1
# 2     19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7  ESI9612311E7
# 3     EAB26414-DD9A-4E8F-9F5C-05FE24D98E48  BLE1512082R9
# 4     C16F79B5-FB35-4BFC-AF84-708B24F500BB  BLE1512082R9
# ...                                    ...           ...
# 3030  83F82167-0D14-144E-9D76-045C95F25DDD  PGM881128QIA
# 3031  B1C60AE0-02BC-4A33-9513-A280F72B5D06  SME0510105C7
# 3032  255F4A25-5753-4208-8F6B-0B59E5AE4741  BMN930209927
# 3033  D8226E4F-9241-44C3-86A4-CDE9BC932528  BIN940223KE0
# 3034  41770F35-39EF-41A4-8DF4-EE9586CF4549  EFE8908015L3
#
#                                               PROVEEDOR  \
# 0                        BANCO NACIONAL DE MEXICO, S.A.
# 1                        BANCO NACIONAL DE MEXICO, S.A.
# 2                ELECTRONICOS Y SIMILARES, S.A. DE C.V.
# 3                          BEPENSA LEASING S.A. DE C.V.
# 4                          BEPENSA LEASING S.A. DE C.V.
# ...                                                 ...
# 3030       PROMOCIONES GRAFICAS MEXICANAS, S.A. DE C.V.
# 3031                      SPECTRIS MEXICO S DE RL DE CV
# 3032  BANCO MERCANTIL DEL NORTE SA INSTITUCION DE BA...
# 3033  BANCO INVEX, S.A., INSTITUCION DE BANCA MULTIP...
# 3034                      EFECTIVALE S. de R.L. de C.V.
#
#                     TIPO GASTO  \
# 0            COMISION BANCARIA
# 1            COMISION BANCARIA
# 2                      COMPRAS
# 3     ARRENDAMIENTO FINANCIERO
# 4     ARRENDAMIENTO FINANCIERO
# ...                        ...
# 3030                PUBLICIDAD
# 3031                  COMPRAS
# 3032         COMISION BANCARIA
# 3033         COMISION BANCARIA
# 3034                  GASOLINA
#
#                                             DESCRIPCION   MP   TC   IMPORTE  \
# 0                                      COMISION COBRADA  PUE  1.0    490.00
# 1                                      COMISION COBRADA  PUE  1.0    345.00
# 2                           MOTO E7 PLUS AZUL 64GB 4RAM  PUE  1.0   3447.41
# 3     AA RENTA EXIGIBLE CL0000006876 6/36 de 03/12/2...  PPD  1.0   5551.38
# 4     AA RENTA EXIGIBLE CL0000006877 6/36 de 03/12/2...  PPD  1.0   5551.98
# ...                                                 ...  ...  ...       ...
# 3030                                               Pago   --  1.0      0.00
# 3031                                 INSULATED T/C WIRE  PUE  1.0      0.00
# 3032                                SERVICIOS BANCARIOS  PUE  1.0  22826.46
# 3033                             COMISIONES E INTERESES  PUE  1.0      0.00
# 3034  CONSUMOS DE COMBUSTIBLE DE MONEDEROS ELECTRONICOS  PUE  1.0  15656.15
#
#          IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT TIPO   STATUS POLIZA
# 0      78.40      0.0      0.0    568.40     568.40    I  Vigente      0
# 1      55.20      0.0      0.0    400.20     400.20    I  Vigente      0
# 2     551.59      0.0      0.0   3999.00    3999.00    I  Vigente      0
# 3     888.22      0.0      0.0   6439.60    6439.60    I  Vigente      0
# 4     888.32      0.0      0.0   6440.30    6440.30    I  Vigente      0
# ...      ...      ...      ...       ...        ...  ...      ...    ...
# 3030    0.00      0.0      0.0      0.00       0.00    P  Vigente     --
# 3031    0.00      0.0      0.0      0.00       0.00    I  Vigente     --
# 3032  705.58      0.0      0.0  23532.04   23532.04    I  Vigente     --
# 3033    0.00      0.0      0.0      0.00       0.00    I  Vigente     --
# 3034    0.00      0.0      0.0  15656.15   15656.15    I  Vigente     --
#
# [3035 rows x 20 columns]

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.9019362036138808

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.949703218702496
